# %% [markdown]
# <img src='./img/opengeohub_logo.png' alt='OpenGeoHub Logo' align='right' width='15%'></img>

# %% [markdown]
# <a href="./00_index.ipynb"><< Index </a><br>
# <a href="./05_google_earth_engine.ipynb"><< 05 - Google Earth Engine </a><span style="float:right;"><a href="./12_covid19_case_study_s5p_time_series_analysis.ipynb"> 12 - Covid-19 - Sentinel-5P time-series analysis >></a></span>

# %% [markdown]
# ### Covid-19 case study

# %% [markdown]
# # Sentinel-5p TROPOMI Tropospheric NO<sub>2</sub> anomaly maps

# %% [markdown]
# This workflow aims at producing an **anomaly map** of tropospheric NO<sub>2</sub> values between 2019 and 2020 of a specific month.
#
# ### Data used
# This workflow uses the following data:
# - Daily Sentinel-5P Level 2 files retrieved from the [Open Data Registry on AWS](https://registry.opendata.aws/sentinel5p/), regridded onto a regular grid and disseminated as `cloud-optimised GeoTiffs`
#
# ### Workflow outline
# The workflow has the following outline:
# - [Define a list with dictionaries holding bounding boxes for different regions](#region_list)
# - [*Optional: Regridding (Binning) of Sentinel-5p daily Level 2 files onto a regular grid*](#binning)
# - [Load daily regular gridded NetCDF files of tropospheric NO<sub>2</sub>](#load_daily_files)
#  - [Resample the tropospheric NO<sub>2</sub> data and generate monthly means](#resample)
#  - [Apply the conversion factor for Sentinel-5P data](#conversion)
#  - [Generate a geographical subset of a specific region](#geographical_subset)
#  - [Visualize the average tropospheric NO<sub>2</sub> for a specific month](#visualize)
# - [Generate an anomaly map between 2019 and 2020 for a specific month](#anomaly)

# %% [markdown]
# #### Load required libraries

# %%
import glob
import os
import xarray as xr
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER

# %% [markdown]
# #### Load helper functions

# %%
from ipynb.fs.full.functions import visualize_pcolormesh, generate_masked_array, generate_geographical_subset

# %% [markdown]
# <hr>

# %% [markdown]
# ## <a id='region_list'></a>Define a list with dictionaries holding bounding boxes for different regions

# %% [markdown]
# You can define several regions as a dictionary, e.g. the bounding box information for `Europe`, the `Po valley` in Italy or the `Hubei region` in China. The dictionaries are stored in a list.

# %%
eur_extent={'name': 'eur_extent',
    'lonmin':-10.0,
            'lonmax':30.0,
            'latmin':35.0,
            'latmax':60.0}

# Italy (Po Valley, Milano)
povalley_extent={'name': 'povalley_extent',
    'lonmin':7.0,
            'lonmax':13.0,
            'latmin':44.0,
            'latmax':47.0}

# China (Hubei, Wuhan)
hubei_extent={'name': 'hubei_extent',
    'lonmin':108.3,
            'lonmax':116.1,
            'latmin':29.1,
            'latmax':33.3}


region_list =[eur_extent,
             povalley_extent,
             hubei_extent]

# %% [markdown]
# <hr>

# %% [markdown]
# ## <a id='binning'></a>*Optional: Regridding (Binning) of Sentinel-5p daily Level 2 files onto a regular grid*

# %% [markdown]
# #### Optional: Create list of `COG` files retrieved from the `Open Data Registry on AWS`

# %%
fileList = glob.glob('../eodata/sentinel5p/no2/*.tif')
fileList_sort = sorted(fileList)

# %% [markdown]
# #### Optional: Generate daily xarray NetCDF files of a re-gridded tropospheric NO<sub>2</sub> values

# %% [markdown]
# Define the latitude and longitude bins, based on a 0.036 x 0.036 grid. Additionally, you have to define the center of each latitude and longitude, which should have one entry less than number of bins defined.

# %%
# Create the bins based on a 0.036 x 0.036 grid
lat_bins = np.arange(-90,90+(0.036/2),0.036)
lon_bins = np.arange(-180,180+(0.036/2), 0.036)

# define a label for each bin corresponding to the central latitude
lat_center = np.arange(-90+(0.036/2),90,0.036)
lon_center = np.arange(-180+(0.036/2),180,0.036)

# %% [markdown]
# #### Define a `unit` and a `longname`

# %%
unit = 'mol/cm2'
longname= 'Tropospheric vertical column of NO2'

# %% [markdown]
# Loop through each entry in the file list and execute the following steps:
# - Open the `COG` file as xarray with the function `xarray.open_rasterio()`
# - Flag out negative values with the function `xarray.where()`
# - Bring the NO2 values onto a regular latitude grid with the function `xarray.groupby_bins()`
# - Repeat the function `xarray.groupby_bins()` to bring the values also onto a regular longitude grid
# - Save the regridded array at `netCDF` file

# %%
for i in range(0,len(fileList_sort)):
        print(i)
        # Open the COG file with rasterio
        tmp = xr.open_rasterio(fileList_sort[i])
        tmp_name = fileList_sort[i].split('_')[8]
        print(tmp_name)
        tmp= tmp.rename({'x': 'lon', 'y':'lat'})
        
        # Flag out negative values
        tmp_flag = tmp.where(tmp>0,np.nan)
        
        # Bring NO2 values onto a regular latitude grid and create the average of multiple values per cell
        tmp_regrid_lat = tmp_flag.groupby_bins('lat', lat_bins, labels=lat_center).mean()
        # Bring NO2 values onto a regular longitude grid
        tmp_regrid = tmp_regrid_lat.groupby_bins('lon', lon_bins, labels=lon_center).mean()
        
        # Create a xarray.DataArray with the regridded array and the define latituden and longitude bins
        data_array = xr.DataArray(
                tmp_regrid.isel(band=0).values,
                dims=['lat','lon'],
                coords={
                    'time': pd.to_datetime(tmp_name),
                    'lat':(['lat'],tmp_regrid.isel(band=0).lat_bins),
                    'lon':(['lon'],tmp_regrid.isel(band=0).lon_bins)
                },
                attrs={'long_name': longname, 'units': unit},
                name='NO2_tropo'
            )
        
        # Save the created xarray.DatArray as netCDF file
        data_array.to_netcdf('./s5p_no2_'+tmp_name+'.nc', 'w')
# Out:
# 0
# 20181017
# 1
# 20181018
# 2
# 20181019
# 3
# 20181020
# 4
# 20181021
# 5
# 20181022
# 6
# 20181023
# 7
# 20181024
# 8
# 20181025
# 9
# 20181026
# 10
# 20181027
# 11
# 20181028
# 12
# 20181029
# 13
# 20181030
# 14
# 20181031
# 15
# 20181101
# 16
# 20181102
# 17
# 20181103
# 18
# 20181104
# 19
# 20181105
# 20
# 20181106
# 21
# 20181107
# 22
# 20181108
# 23
# 20181109
# 24
# 20181110
# 25
# 20181111
# 26
# 20181112
# 27
# 20181113
# 28
# 20181114
# 29
# 20181115
# 30
# 20181116
# 31
# 20181117
# 32
# 20181118
# 33
# 20181119
# 34
# 20181120
# 35
# 20181121
# 36
# 20181122
# 37
# 20181123
# 38
# 20181124
# 39
# 20181125
# 40
# 20181126
# 41
# 20181127
# 42
# 20181128
# 43
# 20181129
# 44
# 20181130
# 45
# 20181201
# 46
# 20181202
# 47
# 20181203
# 48
# 20181204
# 49
# 20181205
# 50
# 20181206
# 51
# 20181207
# 52
# 20181208
# 53
# 20181209
# 20200111
# 359
# 20200112
# 360
# 20200113
# 361
# 20200114
# 362
# 20200115
# 363
# 20200116
# 364
# 20200117
# 365
# 20200118
# 366
# 20200119
# 367
# 20200120
# 368
# 20200121
# 369
# 20200122
# 370
# 20200123
# 371
# 20200124
# 372
# 20200125
# 373
# 20200126
# 374
# 20200127
# 375
# 20200128
# 376
# 20200129
# 377
# 20200130
# 378
# 20200131
# 379
# 20200201
# 380
# 20200202
# 381
# 20200203
# 382
# 20200204
# 383
# 20200205
# 384
# 20200206
# 385
# 20200207
# 386
# 20200208
# 387
# 20200209
# 388
# 20200210
# 389
# 20200211
# 390
# 20200212
# 391
# 20200213
# 392
# 20200214
# 393
# 20200215
# 394
# 20200216
# 395
# 20200217
# 396
# 20200218
# 397
# 20200219
# 398
# 20200220
# 399
# 20200221
# 400
# 20200222
# 401
# 20200223
# 402
# 20200224
# 403
# 20200225
# 404
# 20200226
# 405
# 20200227
# 406
# 20200228
# 407
# 20200229
# 408
# 20200301
# 409
# 20200302
# 410
# 20200303
# 411
# 20200304
# 412
# 20200305
# 413
# 20200306
# 414
# 20200307
# 415
# 20200308
# 416
# 20200309
# 417
# 20200310
# 418
# 20200311
# 419
# 20200312
# 420
# 20200313
# 421
# 20200314
# 422
# 20200315
# 423
# 20200316
# 424
# 20200317
# 425
# 20200318
# 426
# 20200319
# 427
# 20200320
# 428
# 20200321
# 429
# 20200322
# 430
# 20200323
# 431
# 20200324
# 432
# 20200325
# 433
# 20200326
# 434
# 20200327
# 435
# 20200328
# 436
# 20200329
# 437
# 20200330
# 438
# 20200331
# 439
# 20200401
# 440
# 20200402
# 441
# 20200403
# 442
# 20200404
# 443
# 20200405
# 444
# 20200406
# 445
# 20200407
# 446
# 20200408
# 447
# 20200409
# 448
# 20200410
# 449
# 20200411
# 450
# 20200412
# 451
# 20200413
# 452
# 20200414
# 453
# 20200415
# 454
# 20200416
# 455
# 20200417
# 456
# 20200418
# 457
# 20200419
# 458
# 20200420
# 459
# 20200421
# 460
# 20200422
# 461
# 20200423
# 462
# 20200424
# 463
# 20200425
# 464
# 20200426
# 465
# 20200427
# 466
# 20200428
# 467
# 20200429
# 468
# 20200430
# 469
# 20200501
# 470
# 20200502
# 471
# 20200503
# 472
# 20200504
# 473
# 20200505
# 474
# 20200506
# 475
# 20200507
# 476
# 20200508
# 477
# 20200509
# 478
# 20200510
# 479
# 20200511
# 480
# 20200512
# 481
# 20200513
# 482
# 20200514
# 483
# 20200515

# %% [markdown]
# <hr>

# %% [markdown]
# ## <a id='load_daily_files'></a>Load daily regular gridded NetCDF files of tropospheric NO<sub>2</sub>

# %% [markdown]
# Load the `netCDF` files for 2019 and 2020 with the function `xarray.open_mfdataset()` and set the keyword argument `concat_dim='time'`. Do this for both years, 2019 and 2020 respectively.

# %%
ndjfmam_2019 = xr.open_mfdataset('../eodata/sentinel5p/no2/nc/2019/s5p*', concat_dim='time', combine='nested')
no2_tropo_2019=ndjfmam_2019.NO2_tropo
no2_tropo_2019

ndjfmam_2020 = xr.open_mfdataset('../eodata/sentinel5p/no2/nc/2020/s5p*', concat_dim='time', combine='nested')
no2_tropo_2020=ndjfmam_2020.NO2_tropo
no2_tropo_2020
# Out:
# <xarray.DataArray 'NO2_tropo' (time: 197, lat: 5000, lon: 10000)>
# dask.array<concatenate, shape=(197, 5000, 10000), dtype=float32, chunksize=(1, 5000, 10000), chunktype=numpy.ndarray>
# Coordinates:
#   * lon      (lon) float64 -180.0 -179.9 -179.9 -179.9 ... 179.9 179.9 180.0
#   * lat      (lat) float64 -89.98 -89.95 -89.91 -89.87 ... 89.91 89.95 89.98
#   * time     (time) datetime64[ns] 2019-11-01 2019-11-02 ... 2020-05-15
# Attributes:
#     long_name:  Tropospheric vertical column of NO2
#     units:      mol/cm2

# %% [markdown]
# ### <a id='resample'></a>Resample the tropospheric NO<sub>2</sub> data and generate monthly means

# %% [markdown]
# You can temporally resample a `xarray.DataArray` with the function `resample()`. As resample dimension, you specify `time='M'`, which aggregates the daily values to monthly values. You can add a reducer function to the `resample()`, which specifies the manner of aggregation, e.g. `mean()`.
#
# Let us repeat the resample operation for both years, 2019 and 2020. The time dimension has reduced to 7, which indicates the entries for each month from November to May.

# %%
no2_monthly_2019 = no2_tropo_2019.resample(time='M',skipna=False).mean()
no2_monthly_2020 = no2_tropo_2020.resample(time='M',skipna=False).mean()
no2_monthly_2020
# Out:
# <xarray.DataArray 'NO2_tropo' (time: 7, lat: 5000, lon: 10000)>
# dask.array<stack, shape=(7, 5000, 10000), dtype=float32, chunksize=(1, 5000, 10000), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 2019-11-30 2019-12-31 ... 2020-05-31
#   * lon      (lon) float64 -180.0 -179.9 -179.9 -179.9 ... 179.9 179.9 180.0
#   * lat      (lat) float64 -89.98 -89.95 -89.91 -89.87 ... 89.91 89.95 89.98

# %% [markdown]
# ### <a id='conversion'></a>Apply the conversion factor for Sentinel-5P data

# %% [markdown]
# Define the conversion factor

# %%
conversion_factor=6.02214*1e+19

# %% [markdown]
# Apply the conversion factor to the values of the two data arrays

# %%
no2_monthly_2020 = no2_monthly_2020*conversion_factor
no2_monthly_2019 = no2_monthly_2019*conversion_factor

# %% [markdown]
# ### <a id='geographical_subset'></a>Generate a geographical subset of a specific region

# %% [markdown]
# Apply the function `generate_geographical_subset` and generate a subset for a specific region, e.g. Europe.

# %%
region = region_list[0]

no2_monthly_2020 = no2_monthly_2020.rename({'lon': 'longitude', 'lat': 'latitude'})
no2_monthly_2019 = no2_monthly_2019.rename({'lon': 'longitude', 'lat': 'latitude'})

eur20 = generate_geographical_subset(no2_monthly_2020,
                                            region['latmin'],
                                            region['latmax'],
                                            region['lonmin'],
                                            region['lonmax'])
eur19 = generate_geographical_subset(no2_monthly_2019,
                                            region['latmin'],
                                            region['latmax'],
                                            region['lonmin'],
                                            region['lonmax'])

# %%
eur20
# Out:
# <xarray.DataArray 'NO2_tropo' (time: 7, latitude: 695, longitude: 1111)>
# dask.array<where, shape=(7, 695, 1111), dtype=float32, chunksize=(1, 695, 1111), chunktype=numpy.ndarray>
# Coordinates:
#   * time       (time) datetime64[ns] 2019-11-30 2019-12-31 ... 2020-05-31
#   * longitude  (longitude) float64 -9.99 -9.954 -9.918 ... 29.9 29.93 29.97
#   * latitude   (latitude) float64 35.01 35.05 35.08 35.12 ... 59.92 59.96 59.99

# %% [markdown]
# ### <a id='visualize'></a>Visualize the average tropospheric NO<sub>2</sub> for a specific month

# %% [markdown]
# Apply the function [visualize_pcolormesh](./functions.ipynb#visualize_pcolormesh) to plot the monthly tropospheric NO<sub>2</sub> for April 2020.

# %%
visualize_pcolormesh(eur20.isel(time=5)*1e-15, 
                         eur20.isel(time=4).longitude, 
                         eur20.isel(time=4).latitude, 
                         ccrs.PlateCarree(), 
                         'viridis', 
                         '*1e-15 mol/cm2', 
                         no2_tropo_2019.long_name, 
                         0, 8, 
                         region['lonmin'],
                         region['lonmax'],
                         region['latmin'],
                         region['latmax'],
                         log=False, 
                         set_global=False)
# Out:
# (<Figure size 1440x720 with 2 Axes>,
#  <cartopy.mpl.geoaxes.GeoAxesSubplot at 0x7f3d4a105080>)

# %% [markdown]
# ## <a id='anomaly'></a>Generate an anomaly map between 2019 and 2020 for a specific month

# %% [markdown]
# Let us select a specific month, e.g. April and let's generate an anomaly map between the two years 2019 and 2020. We can simply subtract the `xarray.DataArray` of April 2019 from the `xarray.DataArray` of April 2020.

# %%
month = 5 # April
anomaly_1920 = no2_monthly_2020.isel(time=month) - no2_monthly_2019.isel(time=month)
anomaly_1920
# Out:
# <xarray.DataArray 'NO2_tropo' (latitude: 5000, longitude: 10000)>
# dask.array<sub, shape=(5000, 10000), dtype=float32, chunksize=(5000, 10000), chunktype=numpy.ndarray>
# Coordinates:
#   * longitude  (longitude) float64 -180.0 -179.9 -179.9 ... 179.9 179.9 180.0
#   * latitude   (latitude) float64 -89.98 -89.95 -89.91 ... 89.91 89.95 89.98

# %% [markdown]
# ### Select a region and visualize the anomaly map

# %% [markdown]
# Let us choose a region, e.g. Europe, and create a geographical subset with the function [generate_geographical_subset](./functions.ipynb#generate_geographical_subset).

# %%
region = region_list[0]
eur_anomaly = generate_geographical_subset(anomaly_1920,
                                            region['latmin'],
                                            region['latmax'],
                                            region['lonmin'],
                                            region['lonmax'])

# %% [markdown]
# Use the function [visualize_pcolormesh](./functions.ipynb#visualize_pcolormesh) to visualize the anomaly map.

# %%
visualize_pcolormesh(eur_anomaly*1e-15, 
                         eur_anomaly.longitude, 
                         eur_anomaly.latitude, 
                         ccrs.PlateCarree(), 
                         'RdBu_r', 
                         '*1e-15 mol/cm2', 
                         no2_tropo_2019.long_name + 'Anomaly April 2020 to April 2019', 
                         -3, 3, 
                         region['lonmin'],
                         region['lonmax'],
                         region['latmin'],
                         region['latmax'],
                         log=False, 
                         set_global=False)
# Out:
# (<Figure size 1440x720 with 2 Axes>,
#  <cartopy.mpl.geoaxes.GeoAxesSubplot at 0x7f3d482a6978>)

# %% [markdown]
# <br>

# %% [markdown]
# <a href="./05_google_earth_engine.ipynb"><< 05 - Google Earth Engine </a><span style="float:right;"><a href="./12_covid19_case_study_s5p_time_series_analysis.ipynb"> 12 - Covid-19 - Sentinel-5P time-series analysis >></a></span><br>
# <a href="./index.ipynb"><< Index </a>

# %% [markdown]
# <hr>

# %% [markdown]
# <hr>
# &copy; 2020 | Julia Wagemann
# <a rel="license" href="http://creativecommons.org/licenses/by/4.0/"><img style="float: right" alt="Creative Commons Lizenzvertrag" style="border-width:0" src="https://i.creativecommons.org/l/by/4.0/88x31.png" /></a>
